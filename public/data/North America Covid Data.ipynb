# %%
import numpy as np
import pandas as pd
import os
import jovian

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '.jovianrc',
#  'bsg',
#  'ecdc',
#  'gmobility',
#  'owid-covid-codebook.csv',
#  'owid-covid-data-last-updated-timestamp.txt',
#  'owid-covid-data.csv',
#  'owid-covid-data.json',
#  'owid-covid-data.xlsx',
#  'README.md',
#  'testing',
#  'Untitled.ipynb',
#  'who']

# %%
covid_df = pd.read_csv('owid-covid-data.csv')

# %%
covid_df
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2019-12-31          0.0        0.0
# 1          AFG      Asia    Afghanistan  2020-01-01          0.0        0.0
# 2          AFG      Asia    Afghanistan  2020-01-02          0.0        0.0
# 3          AFG      Asia    Afghanistan  2020-01-03          0.0        0.0
# 4          AFG      Asia    Afghanistan  2020-01-04          0.0        0.0
# ...        ...       ...            ...         ...          ...        ...
# 41798      NaN       NaN  International  2020-09-01        696.0        NaN
# 41799      NaN       NaN  International  2020-09-02        696.0        NaN
# 41800      NaN       NaN  International  2020-09-03        696.0        NaN
# 41801      NaN       NaN  International  2020-09-04        696.0        NaN
# 41802      NaN       NaN  International  2020-09-05        696.0        NaN
#
# ...

# %%
covid_df['date'] = pd.to_datetime(covid_df['date'])

# %%
covid_df
# Out:
#       iso_code continent       location       date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan 2019-12-31          0.0        0.0
# 1          AFG      Asia    Afghanistan 2020-01-01          0.0        0.0
# 2          AFG      Asia    Afghanistan 2020-01-02          0.0        0.0
# 3          AFG      Asia    Afghanistan 2020-01-03          0.0        0.0
# 4          AFG      Asia    Afghanistan 2020-01-04          0.0        0.0
# ...        ...       ...            ...        ...          ...        ...
# 41798      NaN       NaN  International 2020-09-01        696.0        NaN
# 41799      NaN       NaN  International 2020-09-02        696.0        NaN
# 41800      NaN       NaN  International 2020-09-03        696.0        NaN
# 41801      NaN       NaN  International 2020-09-04        696.0        NaN
# 41802      NaN       NaN  International 2020-09-05        696.0        NaN
#
# ...

# %%
covid_df[covid_df_NA]
# Out:
#       iso_code      continent       location       date  total_cases  \
# 39313      USA  North America  United States 2019-12-31          0.0
# 39314      USA  North America  United States 2020-01-01          0.0
# 39315      USA  North America  United States 2020-01-02          0.0
# 39316      USA  North America  United States 2020-01-03          0.0
# 39317      USA  North America  United States 2020-01-04          0.0
# ...        ...            ...            ...        ...          ...
# 39558      USA  North America  United States 2020-09-01    6031013.0
# 39559      USA  North America  United States 2020-09-02    6075652.0
# 39560      USA  North America  United States 2020-09-03    6114406.0
# 39561      USA  North America  United States 2020-09-04    6150655.0
# 39562      USA  North America  United States 2020-09-05    6201726.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 39313        0.0                 NaN           0.0         0.0
# ...

# %%
covid_df_NA
# Out:
#       iso_code      continent       location       date  total_cases  \
# 39313      USA  North America  United States 2019-12-31          0.0
# 39314      USA  North America  United States 2020-01-01          0.0
# 39315      USA  North America  United States 2020-01-02          0.0
# 39316      USA  North America  United States 2020-01-03          0.0
# 39317      USA  North America  United States 2020-01-04          0.0
# ...        ...            ...            ...        ...          ...
# 39558      USA  North America  United States 2020-09-01    6031013.0
# 39559      USA  North America  United States 2020-09-02    6075652.0
# 39560      USA  North America  United States 2020-09-03    6114406.0
# 39561      USA  North America  United States 2020-09-04    6150655.0
# 39562      USA  North America  United States 2020-09-05    6201726.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 39313        0.0                 NaN           0.0         0.0
# ...

# %%
covid_df_NA.to_csv('covidNAdata.csv', index=None)

# %%
covid_df_NA.total_cases.first_valid_index()
# Out:
# 39313

# %%
covid_df_NA.total_cases > 0.0
# Out:
# 39313    False
# 39314    False
# 39315    False
# 39316    False
# 39317    False
#          ...
# 39558     True
# 39559     True
# 39560     True
# 39561     True
# 39562     True
# Name: total_cases, Length: 250, dtype: bool

# %%
lowIndex = covid_df_NA.total_cases > 100000
highIndex = covid_df_NA.total_cases < 200000

# %%
covid_df_NA[lowIndex]
# Out:
#       iso_code      continent       location       date  total_cases  \
# 39401      USA  North America  United States 2020-03-28     104686.0
# 39402      USA  North America  United States 2020-03-29     124665.0
# 39403      USA  North America  United States 2020-03-30     143025.0
# 39404      USA  North America  United States 2020-03-31     164620.0
# 39405      USA  North America  United States 2020-04-01     189618.0
# ...        ...            ...            ...        ...          ...
# 39558      USA  North America  United States 2020-09-01    6031013.0
# 39559      USA  North America  United States 2020-09-02    6075652.0
# 39560      USA  North America  United States 2020-09-03    6114406.0
# 39561      USA  North America  United States 2020-09-04    6150655.0
# 39562      USA  North America  United States 2020-09-05    6201726.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 39401    18695.0           12151.714        1707.0       411.0
# ...

# %%
covid_df_NA[highIndex]
# Out:
#       iso_code      continent       location       date  total_cases  \
# 39313      USA  North America  United States 2019-12-31          0.0
# 39314      USA  North America  United States 2020-01-01          0.0
# 39315      USA  North America  United States 2020-01-02          0.0
# 39316      USA  North America  United States 2020-01-03          0.0
# 39317      USA  North America  United States 2020-01-04          0.0
# ...        ...            ...            ...        ...          ...
# 39401      USA  North America  United States 2020-03-28     104686.0
# 39402      USA  North America  United States 2020-03-29     124665.0
# 39403      USA  North America  United States 2020-03-30     143025.0
# 39404      USA  North America  United States 2020-03-31     164620.0
# 39405      USA  North America  United States 2020-04-01     189618.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 39313        0.0                 NaN           0.0         0.0
# ...

# %%
lowIndex.first_valid_index()
# Out:
# 39313

# %%
highIndex.last_valid_index()
# Out:
# 39562

# %%
lowRange = covid_df_NA[]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-d70a9a97ab55> in <module>
# ----> 1 low
#
# NameError: name 'low' is not defined

# %%
lowIndex = covid_df_NA[covid_df_NA.total_cases > 100000].first_valid_index()

# %%
lowIndex
# Out:
# 39401

# %%
highIndex = (covid_slice[covid_df_NA.total_cases < 400000]).last_valid_index()

# %%
highIndex
# Out:
# 39412

# %%
covid_slice = covid_df_NA.loc[lowIndex:highIndex]

# %%
covid_slice
# Out:
#       iso_code      continent       location       date  total_cases  \
# 39401      USA  North America  United States 2020-03-28     104686.0
# 39402      USA  North America  United States 2020-03-29     124665.0
# 39403      USA  North America  United States 2020-03-30     143025.0
# 39404      USA  North America  United States 2020-03-31     164620.0
# 39405      USA  North America  United States 2020-04-01     189618.0
# 39406      USA  North America  United States 2020-04-02     216721.0
# 39407      USA  North America  United States 2020-04-03     245540.0
# 39408      USA  North America  United States 2020-04-04     277965.0
# 39409      USA  North America  United States 2020-04-05     312237.0
# 39410      USA  North America  United States 2020-04-06     337635.0
# 39411      USA  North America  United States 2020-04-07     368196.0
# 39412      USA  North America  United States 2020-04-08     398809.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
covid_slice.to_csv('covidNAdata.csv')

# %%
covid_slice.new_cases.plot()
# Out:
# <AxesSubplot:>

# %%
covid_slice.set_index('date', inplace=True)

# %%
covid_slice
# Out:
#            iso_code      continent       location  total_cases  new_cases  \
# date
# 2020-03-28      USA  North America  United States     104686.0    18695.0
# 2020-03-29      USA  North America  United States     124665.0    19979.0
# 2020-03-30      USA  North America  United States     143025.0    18360.0
# 2020-03-31      USA  North America  United States     164620.0    21595.0
# 2020-04-01      USA  North America  United States     189618.0    24998.0
# 2020-04-02      USA  North America  United States     216721.0    27103.0
# 2020-04-03      USA  North America  United States     245540.0    28819.0
# 2020-04-04      USA  North America  United States     277965.0    32425.0
# 2020-04-05      USA  North America  United States     312237.0    34272.0
# 2020-04-06      USA  North America  United States     337635.0    25398.0
# 2020-04-07      USA  North America  United States     368196.0    30561.0
# 2020-04-08      USA  North America  United States     398809.0    30613.0
#
# ...

# %%
covid_slice.new_cases_per_million.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
covid_df_NA.new_cases.plot()
covid_df_NA.new_deaths.plot()
# Out:
# <AxesSubplot:>

# %%
covid_df_NA_byMonth = covid_df_NA.copy()

# %%
covid_df_NA_byMonth.set_index('date', inplace=True)

# %%
covid_df_NA_byMonth.new_cases.plot()
covid_df_NA_byMonth.new_deaths.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import jovian
jovian.commit(project='Covid-data-practice-andrewt')
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Creating a new project "jandrewtomich/Covid-data-practice-andrewt"
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/jandrewtomich/covid-data-practice-andrewt
# 'https://jovian.ml/jandrewtomich/covid-data-practice-andrewt'
